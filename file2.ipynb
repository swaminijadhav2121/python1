# %%
s1 = input("enter your age:")
# Out:
# enter your age: 16

# %%
name = input("Enter your name: ")
print(name)
# Out:
# Enter your name:  om
# om

# %%
print("Hello")
# Out:
# Hello

# %%
age = int(input("Enter your age: "))

print(age)
print(type(age))
# Out:
# Enter your age:  45
# 45
# <class 'int'>

# %%
print("Python", "Java", "C++",sep="  ")
# Out:
# Python  Java  C++

# %%
print("Hello",end="      ")
print("World")
# Out:
# Hello      World

# %%
print("Hello\nWorld")
# Out:
# Hello
# World

# %%
print("Name\tAge")
print("Swamini\t22")
# Out:
# Name	Age
# Swamini	22

# %%
print("C:\\Users\\Admin\\OneDrive\\Desktop\\python1")
# Out:
# C:\Users\Admin\OneDrive\Desktop\python1

# %%
print('It\'s Python')
# Out:
# It's Python

# %%
print("She said,\"Hello!\"")
# Out:
# She said,"Hello!"

# %%
name = "Swamini"
age = 22

print("My name is " + name + " and I am " + str(age) + " years old.")
# Out:
# My name is Swamini and I am 22 years old.

# %%
name = "Swamini"
age = 22

print(f"My name is {name} and I am {age} years old.")
# Out:
# My name is Swamini and I am 22 years old.

# %%
age = 20

if age >= 18:
    print("You are eligible to vote.")
# Out:
# You are eligible to vote.

# %%
num = int(input("Enter a number: "))

if num % 2 == 0:
    print("Even Number")
else:
    print("Odd Number")
# Out:
# Enter a number:  44
# Even Number

# %%
marks = int(input("Enter Marks: "))

if marks >= 90:
    print("Grade A")
elif marks >= 75:
    print("Grade B")
elif marks >= 50:
    print("Grade C")
elif marks >= 35:
    print("Pass")
else:
    print("Fail")
# Out:
# Enter Marks:  56
# Grade C

# %%
color = input("Enter signal color: ")

if color == "red":
    print("Stop")
elif color == "yellow":
    print("Wait")
elif color == "green":
    print("Go")
else:
    print("Invalid Signal")
# Out:
# Enter signal color:  green
# Go

# %%
username = "admin"
password = "1234"

if username == "admin":
    if password == "1234":
        print("Login Successful")
    else:
        print("Wrong Password")
else:
    print("Wrong Username")
# Out:
# Login Successful
