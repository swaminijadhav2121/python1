# %%
#If()
age = 20
if age>=18:
   print("person eligiable to vote")
# Out:
# person eligiable to vote

# %%
#If()
num = int(input("Enter a number: "))

if num > 0:
    print("Positive Number")
# Out:
# Enter a number:  23
# Positive Number

# %%
#IF()
num = int(input("Enter a number:"))

if num / 5:
    print("divisible by 5")
# Out:
# Enter a number: 25
# divisible by 5

# %%
#if...else
salary = 80000
if salary > 20000:
    print("high salary")
else:
    print("less salary")
# Out:
# high salary

# %%
#if...else
num = int(input("enter a number:"))

if num %2==0:
    print("even numbers")
else:
    print("odd numbers")
# Out:
# enter a number: 5
# odd numbers

# %%
#if...else

num = int(input("Enter a number: "))

if num > 0:
    print("Positive Numbers")
else:
    print("Negative Numbers")
# Out:
# Enter a number:  -24
# Negative Numbers

# %%
#if...elif...else
marks =int(input("enter your marks:"))
if marks >=90:
    print("Grade A")
elif marks >=80:
    print("Grade B")
elif marks >=60:
    print("Grade c")
elif marks >=40:
    print("Grade D")
else:
    print("fail")
# Out:
# enter your marks: 80
# Grade B

# %%
age = int(input("Enter your age: "))

if age >= 0 and age <= 12:
    print("Child")
elif age >= 13 and age <= 19:
    print("Teenager")
elif age >= 20 and age <= 59:
    print("Adult")
elif age >= 60:
    print("Senior Citizen")
else:
    print("Invalid Age")
# Out:
# Enter your age:  60
# Senior Citizen

# %%
month = int(input("Enter month number (1-12): "))

if month == 1:
    print("January")
elif month == 2:
    print("February")
elif month == 3:
    print("March")
elif month == 4:
    print("April")
elif month == 5:
    print("May")
elif month == 6:
    print("June")
elif month == 7:
    print("July")
elif month == 8:
    print("August")
elif month == 9:
    print("September")
elif month == 10:
    print("October")
elif month == 11:
    print("November")
elif month == 12:
    print("December")
else:
    print("Invalid Month")
# Out:
# Enter month number (1-12):  7
# July

# %%
#nested if
username = input("Enter Username: ")
password = input("Enter Password: ")

if username == "admin":
    if password == "1234":
        print("Login Successful")
    else:
        print("Invalid Password")
else:
    print("Invalid Username")
# Out:
# Enter Username:  admin
# Enter Password:  1234
# Login Successful

# %%
percentage = float(input("Enter Percentage: "))
entrance_marks = int(input("Enter Entrance Exam Marks: "))

if percentage >= 60:
    if entrance_marks >= 70:
        print("Admission Confirmed")
    else:
        print("Admission Rejected")
else:
    print("Admission Rejected")
# Out:
# Enter Percentage:  67
# Enter Entrance Exam Marks:  78
# Admission Confirmed
