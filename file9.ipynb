# %%
def add(a, b):
    return a+b
print(add(10, 20))
print(add(30, 40))
print(add(50, 60))
# Out:
# 30
# 70
# 110

# %%
def add(a,b):
    return a+b
print(add(10,20))
# Out:
# 30

# %%
def greet():
    print("hello")
greet()
# Out:
# hello

# %%
def add(a,b):
    return a+b
    result = (add(10,20))
    print(result)

# %%
#print()
def greet():
    print("hello")
    print("python")
greet()
# Out:
# hello
# python

# %%
#return()
def greet():
    print("hello")
    return
    print("python")
greet()
# Out:
# hello

# %%
#defined()
def text():
    print("hello")

# %%
#function call
def text():
    print("hello")
text()
# Out:
# hello

# %%
#parameters()
def greet(name):
    print("hello",name)

# %%
#argument
def greet(name):
    print("hello",name)
greet("swamini")
# Out:
# hello swamini

# %%
#function wthout return
def greet():
    print("hello")
result = greet()
print(result)
# Out:
# hello
# None

# %%
#function with return
def square(number):
    return number * number
result = square(5)
print(result)
# Out:
# 25

# %%
#positional argument
def student(name,age):
    print(name)
    print(age)
student("swamini",21)
# Out:
# swamini
# 21

# %%
#keyword argument
def student(name,age):
    print(name)
    print(age)
student(name="swamini",age=21)
# Out:
# swamini
# 21

# %%
#default argument
def greet(name="user"):
    print("hello",name)
greet("swamini")
# Out:
# hello swamini
