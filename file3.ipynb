# %%
#input
password=(input("enter your password:"))
print(password)
print(type(password))
# Out:
# enter your password: swamini
# swamini
# <class 'str'>

# %%
password = float(input("enter your password:"))
print(password)
print(type(password))
# Out:
# enter your password: 75.50
# 75.5
# <class 'float'>

# %%
age = int(input("Enter age: "))

print(age)
print(type(age))
# Out:
# Enter age:  21
# 21
# <class 'int'>

# %%
#parameters
print("Hello")
print("World")
# Out:
# Hello
# World

# %%
print("Python", end="-")
print("Programming")
# Out:
# Python-Programming

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

print("Difference =", a - b)
# Out:
# Enter first number:  23
# Enter second number:  12
# Difference = 11

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

print("Product =", a * b)
# Out:
# Enter first number:  54
# Enter second number:  23
# Product = 1242

# %%
#escap character
#\n new line
print("Python\nJava\nC++")
# Out:
# Python
# Java
# C++

# %%
#\n new line
print("programing\nlanguage")
# Out:
# programing
# language

# %%
#\t tab space
print("Name\tAdress")
print("Swamini\tUgaon")
# Out:
# Name	Adress
# Swamini	Ugaon

# %%
#\\blackshlash
print("C:\\Users\\Admin")
# Out:
# C:\Users\Admin

# %%
#\' single quote
print('that\'s')
# Out:
# that's

# %%
print('It\'s Python')
# Out:
# It's Python

# %%
#\" double quote
print("It\"s Python")
